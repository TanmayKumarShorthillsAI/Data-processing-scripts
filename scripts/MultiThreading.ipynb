# %%
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from datetime import date, datetime

# %%
df = pd.read_csv("../files/customers-100000.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              100000 non-null  int64
#  1   Customer Id        100000 non-null  object
#  2   First Name         100000 non-null  object
#  3   Last Name          100000 non-null  object
#  4   Company            100000 non-null  object
#  5   City               100000 non-null  object
#  6   Country            100000 non-null  object
#  7   Phone 1            100000 non-null  object
#  8   Phone 2            100000 non-null  object
#  9   Email              100000 non-null  object
#  10  Subscription Date  100000 non-null  object
#  11  Website            100000 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 9.2+ MB

# %%
df['First Name'].unique
# Out:
# <bound method Series.unique of 0           Jared
# 1           Marie
# 2          Elijah
# 3          Sheryl
# 4          Jeremy
#            ...
# 99995        Dana
# 99996    Gabriela
# 99997     Mikayla
# 99998      Javier
# 99999      Kaylee
# Name: First Name, Length: 100000, dtype: object>

# %%
df["Full Name"] = ''
df["Subscription duration"] = ''
df["Phone 1"] = df["Phone 1"].str.replace(".", "-")

# %%
d1 = date.fromisoformat(df["Subscription Date"][0])
d2 = date.today()
delta = d2-d1
delta.days
# Out:
# 1133

# %%
def add_columns():
    print(f"updating index: {index} ")
    df2.at[index, "Full Name"] = row["First Name"] + " " + row["Last Name"]
    delta = date.today() - date.fromisoformat(row["Subscription Date"])
    df2.at[index, "Subscription duration"] = f'{delta.days} Days'

# %%
df2 = df.copy()
for index, row in df2.iterrows():
    with ThreadPoolExecutor(max_workers = 10) as executor:
        futures = []
        futures.append(executor.submit(add_columns))
        for future in futures:
            try:
                future.result()
            except Exception as e:
                print(e)
df2.head()
# Out:
# updating index: 0
# updating index: 1
# updating index: 2
# updating index: 3
# updating index: 4
# updating index: 5
# updating index: 6
# updating index: 7
# updating index: 8
# updating index: 9
# updating index: 10
# updating index: 11
# updating index: 12
# updating index: 13
# updating index: 14
# updating index: 15
# updating index: 16
# updating index: 17
# updating index: 18
# updating index: 19
# updating index: 20
# updating index: 21
# updating index: 22
# updating index: 23
# updating index: 24
# updating index: 25
# updating index: 26
# updating index: 27
# updating index: 28
# updating index: 29
# updating index: 30
# updating index: 31
# updating index: 32
# updating index: 33
# updating index: 34
# updating index: 35
# updating index: 36
# updating index: 37
# updating index: 38
# updating index: 39
# updating index: 40
# updating index: 41
# updating index: 42
# updating index: 43
# updating index: 44
# updating index: 45
# updating index: 46
# updating index: 47
# ...

# %%
df2.to_csv("./outputs/customers-data.csv")
